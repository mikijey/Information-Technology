# %%
print("Hello")
A=10
print(A)
print('A man, \nA plan, \nA canal: \nPanama.')
myStr = "today's date is %d of %s of the year %d"
print(myStr % (20, "january", 2020))
myStr="To print a \"Backslash\" we can duplicate the char '\\'"
print(myStr)
myStr="0123456789abcdefghi"
print(myStr[9])
Z=myStr
print( Z[3:11])
myList = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
print(myList)
myList.append('Saturday')
print(myList)
print(myList[3])
LastItem = myList.pop()
print(LastItem)
print(myList)
print(myList[:3])
myTupple = (55,97,82,85,87,99,88,64,88,62)
print(myTupple)
print(myTupple[3])
a={1,2,3,4}
b={3,4,5,6}
print(a.union(b))
print(a.intersection(b))
print(b.difference(a))
print(a.symmetric_difference(b))
WhatToTest = input("What do you want to test?:")
if WhatToTest in "aeiouAEIOU":
    print("%s is a vowel" % WhatToTest)
else:
    print("%s is NOT vowel" % WhatToTest)

A = input("Side of the square:")
x = int(A)*4
y = int(A)*int(A)
print("perimeter:", x, "- area:",y)


D = input("Grade of 1st test:")
E = input("Grade of 2nd test:")
R = input("Grade of 3rd test:")
U = input("Grade of 4th test:")
C = float(D) + float(E) + float(R) + float(U)
Avggrades = C / 4
print("Average:", Avggrades)


nr=int(input("Number?"))
if nr % 2 ==0:
    print("Number",nr, "is Even")
else:
    print("Number",nr,"is Odd")
# Out:
# Hello
# 10
# A man,
# A plan,
# A canal:
# Panama.
# today's date is 20 of january of the year 2020
# To print a "Backslash" we can duplicate the char '\'
# 9
# 3456789a
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
# Thursday
# Saturday
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
# ['Monday', 'Tuesday', 'Wednesday']
# (55, 97, 82, 85, 87, 99, 88, 64, 88, 62)
# 85
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {5, 6}
# {1, 2, 5, 6}
# d is NOT vowel
# perimeter: 12 - area: 9
# Average: 3.0
# Number 8 is Even
